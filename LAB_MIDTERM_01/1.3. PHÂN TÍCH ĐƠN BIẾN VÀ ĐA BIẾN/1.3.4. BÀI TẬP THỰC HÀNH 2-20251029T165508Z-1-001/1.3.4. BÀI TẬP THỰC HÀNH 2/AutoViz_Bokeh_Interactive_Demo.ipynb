# %%
# !pip install autoviz
import pandas as pd
import numpy as np
from autoviz import AutoViz_Class
# Out:
# Collecting autoviz
#   Downloading autoviz-0.1.905-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: xlrd in /usr/local/python/3.12.1/lib/python3.12/site-packages (from autoviz) (2.0.2)
# Requirement already satisfied: wordcloud in /usr/local/python/3.12.1/lib/python3.12/site-packages (from autoviz) (1.9.4)
# Collecting emoji (from autoviz)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting pyamg (from autoviz)
#   Downloading pyamg-5.3.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: scikit-learn in /home/codespace/.local/lib/python3.12/site-packages (from autoviz) (1.7.0)
# Requirement already satisfied: statsmodels in /usr/local/python/3.12.1/lib/python3.12/site-packages (from autoviz) (0.14.5)
# Collecting nltk (from autoviz)
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting textblob (from autoviz)
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting xgboost<1.7,>=0.82 (from autoviz)
#   Downloading xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: fsspec>=0.8.3 in /home/codespace/.local/lib/python3.12/site-packages (from autoviz) (2024.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from autoviz) (4.15.0)
# Collecting pandas-dq>=1.29 (from autoviz)
#   Downloading pandas_dq-1.29-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from autoviz) (2.1.3)
# Collecting hvplot>=0.9.2 (from autoviz)
#   Downloading hvplot-0.12.1-py3-none-any.whl.metadata (19 kB)
# Collecting holoviews>=1.16.0 (from autoviz)
#   Downloading holoviews-1.21.0-py3-none-any.whl.metadata (10 kB)
# Collecting panel>=1.4.0 (from autoviz)
#   Downloading panel-1.8.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pandas>=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from autoviz) (2.3.3)
# Requirement already satisfied: matplotlib>3.7.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from autoviz) (3.10.0)
# Requirement already satisfied: seaborn>0.12.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: scipy in /usr/local/python/3.12.1/lib/python3.12/site-packages (from xgboost<1.7,>=0.82->autoviz) (1.15.3)
# Collecting bokeh>=3.1 (from holoviews>=1.16.0->autoviz)
#   Downloading bokeh-3.8.0-py3-none-any.whl.metadata (10 kB)
# Collecting colorcet (from holoviews>=1.16.0->autoviz)
#   Downloading colorcet-3.1.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /usr/local/python/3.12.1/lib/python3.12/site-packages (from holoviews>=1.16.0->autoviz) (25.0)
# Collecting param<3.0,>=2.0 (from holoviews>=1.16.0->autoviz)
#   Downloading param-2.2.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting pyviz-comms>=2.1 (from holoviews>=1.16.0->autoviz)
#   Downloading pyviz_comms-3.0.6-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (1.3.3)
# Requirement already satisfied: narwhals>=1.13 in /home/codespace/.local/lib/python3.12/site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (1.46.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (11.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in /home/codespace/.local/lib/python3.12/site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.5.1)
# Collecting xyzservices>=2021.09.1 (from bokeh>=3.1->holoviews>=1.16.0->autoviz)
#   Downloading xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->autoviz) (2.1.5)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>3.7.4->autoviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>3.7.4->autoviz) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>3.7.4->autoviz) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>3.7.4->autoviz) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib>3.7.4->autoviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: bleach in /home/codespace/.local/lib/python3.12/site-packages (from panel>=1.4.0->autoviz) (6.2.0)
# Collecting linkify-it-py (from panel>=1.4.0->autoviz)
#   Downloading linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting markdown (from panel>=1.4.0->autoviz)
#   Downloading markdown-3.9-py3-none-any.whl.metadata (5.1 kB)
# Collecting markdown-it-py (from panel>=1.4.0->autoviz)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting mdit-py-plugins (from panel>=1.4.0->autoviz)
#   Downloading mdit_py_plugins-0.5.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests in /usr/local/python/3.12.1/lib/python3.12/site-packages (from panel>=1.4.0->autoviz) (2.32.5)
# Requirement already satisfied: tqdm in /usr/local/python/3.12.1/lib/python3.12/site-packages (from panel>=1.4.0->autoviz) (4.67.1)
# Requirement already satisfied: six>=1.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>3.7.4->autoviz) (1.17.0)
# Collecting joblib>=1.2.0 (from scikit-learn->autoviz)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn->autoviz) (3.6.0)
# Requirement already satisfied: webencodings in /home/codespace/.local/lib/python3.12/site-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Collecting uc-micro-py (from linkify-it-py->panel>=1.4.0->autoviz)
#   Downloading uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting mdurl~=0.1 (from markdown-it-py->panel>=1.4.0->autoviz)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: click in /usr/local/python/3.12.1/lib/python3.12/site-packages (from nltk->autoviz) (8.3.0)
# Collecting regex>=2021.8.3 (from nltk->autoviz)
#   Downloading regex-2025.9.18-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from requests->panel>=1.4.0->autoviz) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from requests->panel>=1.4.0->autoviz) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from requests->panel>=1.4.0->autoviz) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from requests->panel>=1.4.0->autoviz) (2025.10.5)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from statsmodels->autoviz) (1.0.1)
# Downloading autoviz-0.1.905-py3-none-any.whl (67 kB)
# Downloading xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl (255.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 59.1 MB/s  0:00:04m0:00:0100:01
# Downloading holoviews-1.21.0-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 53.0 MB/s  0:00:00
# Downloading param-2.2.1-py3-none-any.whl (119 kB)
# Downloading bokeh-3.8.0-py3-none-any.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 48.6 MB/s  0:00:00
# Downloading hvplot-0.12.1-py3-none-any.whl (175 kB)
# Downloading colorcet-3.1.0-py3-none-any.whl (260 kB)
# Downloading pandas_dq-1.29-py3-none-any.whl (29 kB)
# Downloading panel-1.8.2-py3-none-any.whl (30.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.1/30.1 MB 56.1 MB/s  0:00:006m0:00:01
# Downloading pyviz_comms-3.0.6-py3-none-any.whl (84 kB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading xyzservices-2025.4.0-py3-none-any.whl (90 kB)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 18.4 MB/s  0:00:00
# Downloading linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Downloading markdown-3.9-py3-none-any.whl (107 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading mdit_py_plugins-0.5.0-py3-none-any.whl (57 kB)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 36.4 MB/s  0:00:00
# Downloading regex-2025.9.18-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (802 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.0/802.0 kB 33.1 MB/s  0:00:00
# Downloading pyamg-5.3.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 48.1 MB/s  0:00:00
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.3/624.3 kB 27.7 MB/s  0:00:00
# Downloading uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Installing collected packages: xyzservices, uc-micro-py, regex, param, mdurl, markdown, joblib, emoji, colorcet, xgboost, pyviz-comms, pyamg, nltk, markdown-it-py, linkify-it-py, textblob, pandas-dq, mdit-py-plugins, bokeh, panel, holoviews, hvplot, autoviz
#   Attempting uninstall: joblib0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/23 [param]
#     Found existing installation: joblib 1.1.1━━━━━━━━━━━━━━━━━  3/23 [param]
#     Uninstalling joblib-1.1.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/23 [param]
#       Successfully uninstalled joblib-1.1.1━━━━━━━━━━━━━━━━━━━  3/23 [param]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/23 [autoviz]1/23 [hvplot]ws]
# Successfully installed autoviz-0.1.905 bokeh-3.8.0 colorcet-3.1.0 emoji-2.15.0 holoviews-1.21.0 hvplot-0.12.1 joblib-1.5.2 linkify-it-py-2.0.3 markdown-3.9 markdown-it-py-4.0.0 mdit-py-plugins-0.5.0 mdurl-0.1.2 nltk-3.9.2 pandas-dq-1.29 panel-1.8.2 param-2.2.1 pyamg-5.3.0 pyviz-comms-3.0.6 regex-2025.9.18 textblob-0.19.0 uc-micro-py-1.0.3 xgboost-1.6.2 xyzservices-2025.4.0
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
AV = AutoViz_Class()

# %%
datapath = ''  
file_path = "/workspaces/KTLT-ECO-CT7/Lab_MidTerm_1/marketing_campaign_clean.csv"
sep = ',' 
target = ''

# %%
import pandas as pd

file_path = "/workspaces/KTLT-ECO-CT7/Lab_MidTerm_1/marketing_campaign_clean.csv"
df = pd.read_csv(file_path, sep=',')
dft = df[:]
print("Shape:", df.shape)
df.head(1)
# Out:
# Shape: (2240, 29)
#     ID   Year_Birth  Education  Marital_Status  Income   Kidhome  Teenhome  \
# 0  5524     1957     Graduation     Single      58138.0     0         0
#
#   Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0  2012-09-04    58        635       88            546              172
#
#    MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# 0         88              88               3                 8
#
#    NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  \
# 0          10                   4                  7                0
#
#    AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  \
# 0        0             0             0             0           0
#
#    Z_CostContact  Z_Revenue  Response
# 0        3           11          1

# %%
from autoviz import AutoViz_Class

AV = AutoViz_Class()
dft = AV.AutoViz(
    filename=file_path,      
    sep=',',                
    depVar='chas',           
    dfte="",                 
    header=0,                
    lowess=False, 
    chart_format='bokeh',    
    max_rows_analyzed=150000,
    max_cols_analyzed=30
)
# Out:
# Shape of your Data Set loaded: (2240, 29)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  1
#     Number of Integer-Categorical Columns =  15
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  7
#     Number of Discrete String Columns =  1
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  2
#     29 Predictors classified...
#         3 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['ID', 'Z_CostContact', 'Z_Revenue']
# Could not find given target var in data set. Please check input
# Not able to read or load file. Please check your inputs and try again... not enough values to unpack (expected 11, got 8)

# %% [markdown]
# ## Kết thúc
