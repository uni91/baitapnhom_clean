# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
penguins_data = pd.read_csv("penguins_size.csv")
penguins_data = penguins_data[['species', 'culmen_length_mm']]

# %%
import os
print(os.getcwd())  # xem thư mục hiện tại
print(os.listdir())  # liệt kê file và thư mục trong đó
# Out:
# /workspaces/KTLT-ECO-CT7/Lab_MidTerm_1
# ['HousingPrices-Amsterdam-August-2021.csv', '1.3.2 Bài làm mẫu.ipynb', 'Bài tập thực hành 1 .ipynb', 'penguins_lter.csv', '.ipynb_checkpoints', 'penguins_size.csv', '1.2.2 Bài làm mẫu.ipynb']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
penguins_data = pd.read_csv("penguins_size.csv")
penguins_data = penguins_data[['species', 'culmen_length_mm']]

# case 1: basic
sns.histplot(data=penguins_data, x=penguins_data["culmen_length_mm"])

# case 2: advanced
plt.figure(figsize=(12,6))
ax = sns.histplot(data=penguins_data, x=penguins_data["culmen_length_mm"])
ax.set_xlabel('Culmen Length in mm', fontsize=15)
ax.set_ylabel('Count of records', fontsize=15)
ax.set_title('Univariate analysis of Culmen Length', fontsize=20)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
penguins_data = pd.read_csv("/workspaces/KTLT-ECO-CT7/Lab_MidTerm_1/penguins_size.csv")
penguins_data = penguins_data[['species','culmen_length_mm']]

# CASE 1: basic
sns.countplot(data=penguins_data, x='species', palette='pastel')
plt.show()

# CASE 2: advanced 
plt.figure(figsize=(12,6))
ax = sns.countplot(
    data=penguins_data,
    x='species',
    palette='Set2'   
)
ax.set_xlabel('Penguin Species', fontsize=15)
ax.set_ylabel('Count of Records', fontsize=15)
ax.set_title('Univariate Analysis of Penguin Species', fontsize=20)
plt.show()
# Out:
# /tmp/ipykernel_581/1716568508.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=penguins_data, x='species', palette='pastel')
# /tmp/ipykernel_581/1716568508.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %%
penguins_group = penguins_data.groupby('species').count() 
penguins_group = penguins_group.reset_index() 
# case 1: basic 
plt.pie(penguins_group["culmen_length_mm"], labels = 
                      penguins_group['species']) 
plt.show() 
# case 2: advanced 
cols = ['g', 'b', 'r'] 
plt.pie(penguins_group["culmen_length_mm"], labels = 
                          penguins_group['species'],colors = cols) 
plt.title('Univariate Analysis of Species', fontsize=15) 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

houseprices_data = pd.read_csv("HousingPrices-Amsterdam-August-2021.csv")
houseprices_data = houseprices_data[['Zip', 'Price', 'Area', 'Room']]
houseprices_data['PriceperSqm'] = houseprices_data['Price'] / houseprices_data['Area']

plt.figure(figsize=(12,6))
ax = sns.boxplot(data=houseprices_data, x=houseprices_data["Price"])
ax.set_xlabel('House Prices in euros', fontsize=15)
ax.set_title('Univariate Analysis of House Prices', fontsize=20)
plt.ticklabel_format(style='plain', axis='x')  # hiển thị trục x bình thường
plt.show()

# %%
# case 1: basic 
sns.violinplot(data = houseprices_data, x= houseprices_data["Price"]) 
# case 2: advanced 
plt.figure(figsize= (12,6)) 
ax = sns.violinplot(data = houseprices_data, x=houseprices_data["Price"]) 
ax.set_xlabel('House Prices in millions',fontsize = 15) 
ax.set_title('Univariate analysis of House Prices', fontsize= 20) 
plt.ticklabel_format(style='plain', axis='x')

# %%
houseprices_data.describe()
# Out:
#               Price        Area        Room   PriceperSqm
# count  9.200000e+02  924.000000  924.000000    920.000000
# mean   6.220654e+05   95.952381    3.571429   6479.852299
# std    5.389942e+05   57.447436    1.592332   2219.265218
# min    1.750000e+05   21.000000    1.000000   2430.555556
# 25%    3.500000e+05   60.750000    3.000000   4649.086379
# 50%    4.670000e+05   83.000000    3.000000   6578.947368
# 75%    7.000000e+05  113.000000    4.000000   7768.912530
# max    5.950000e+06  623.000000   14.000000  25252.808989

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
penguins_data = pd.read_csv("penguins_size.csv")
penguins_data = penguins_data[['species', 'culmen_length_mm', 'body_mass_g']]

# Case 1: basic scatterplot
sns.scatterplot(data=penguins_data, 
                x='culmen_length_mm', 
                y='body_mass_g')

# Case 2: advanced histogram (2D)
plt.figure(figsize=(12,6))
ax = sns.histplot(data=penguins_data, 
                  x='culmen_length_mm', 
                  y='body_mass_g', 
                  bins=30)  # thêm số bins nếu muốn
ax.set_title('Bivariate Analysis of Culmen Length vs Body Mass', fontsize=20)
plt.show()

# %%
import pandas as pd
penguins_data = pd.read_csv("penguins_size.csv")
penguins_data = penguins_data[['species', 'sex', 'culmen_length_mm', 'body_mass_g']]
table = pd.crosstab(index=penguins_data['species'], columns=penguins_data['sex'])
print(table)
# Out:
# sex        .  FEMALE  MALE
# species
# Adelie     0      73    73
# Chinstrap  0      34    34
# Gentoo     1      58    61

# %%
import seaborn as sns 
sns.pairplot( data = penguins_data)

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import os
os.makedirs("Reports", exist_ok=True)
marketing_data = pd.read_csv("/workspaces/KTLT-ECO-CT7/Lab_MidTerm_1/marketing_campaign_clean.csv")
profile = ProfileReport(marketing_data)
profile.to_file("Reports/profile_output_final.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/29 [00:00<?, ?it/s]
#  10%|█         | 3/29 [00:01<00:12,  2.06it/s]
#  28%|██▊       | 8/29 [00:01<00:03,  6.26it/s]
# 100%|██████████| 29/29 [00:01<00:00, 16.39it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import dtale
import pandas as pd

file_path = "/workspaces/KTLT-ECO-CT7/Lab_MidTerm_1/marketing_campaign_clean.csv"
df = pd.read_csv(file_path)
d = dtale.show(df)
d.open_browser()

# %% [markdown]
# ## Kết thúc
